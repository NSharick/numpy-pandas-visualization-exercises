# %% [markdown]
# Advanced Dataframes Exercises

# %%
import pandas as pd
import numpy as np
from pydataset import data

# %% [markdown]
# Exercises 1

# %%
#1 and 2 completed in the terminal

# %%
#3 - Create a function named get_db_url. 
#It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.
from env import host, username, password

get_db_url = f'mysql+pymysql://{username}:{password}@{host}/employees'

# %%
#4 - Use your function to obtain a connection to the employees database
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', get_db_url)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %%
#5a -  Intentionally make a typo in the database url. What kind of error message do you see?
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)
#returns a "name 'url' is not defined" error message
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/n7/fjb2f8gd5jg17xlxz1c85vhc0000gn/T/ipykernel_38715/2714481500.py in <module>
#       1 #5
# ----> 2 pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)
#
# NameError: name 'url' is not defined

# %%
#5b - Intentionally make an error in your SQL query. What does the error message look like?
pd.read_sql('SELECT FROM employees LIMIT 5 OFFSET 50', get_db_url)
#returns "you have an error in your sql syntax..." error message
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ...

# %%
#6 Read the employees and titles tables into two separate DataFrames
employees = pd.read_sql('SELECT * FROM employees', get_db_url)
titles = pd.read_sql('SELECT * FROM titles', get_db_url)

# %%
#7 - How many rows and columns do you have in each DataFrame?
employees.shape
#300024 rows and 6 columns
# Out:
# (300024, 6)

# %%
#7
titles.shape
#443308 rows and 4 columns
# Out:
# (443308, 4)

# %%
#8 - Display the summary statistics for each DataFrame.
employees.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
#8
titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %%
#9 - How many unique titles are in the titles DataFrame?
titles.nunique()
#there are 7 unique titles
# Out:
# emp_no       300024
# title             7
# from_date      6393
# to_date        5888
# dtype: int64

# %%
#10 - What is the oldest date in the to_date column?
titles.sort_values(by='to_date').head(1)
#returns a to_date of '1985-03-01'
# Out:
#        emp_no     title   from_date     to_date
# 16064   20869  Engineer  1985-02-17  1985-03-01

# %%
#11 - What is the most recent date in the to_date column?
titles.sort_values(by='to_date', ascending=False).head(1)
#returns a to_date of '9999-01-01'
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01

# %% [markdown]
# Exercises 2

# %%
#1 - Copy the users and roles DataFrames from the examples above.
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})

# %%
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
#2 - What is the result of using a right join on the DataFrames?
users.merge(roles, how='right')
# Out:
#    id       name  role_id
# 0   1      admin      NaN
# 1   2     author      NaN
# 2   3   reviewer      NaN
# 3   4  commenter      NaN

# %%
#adding the left_on and right_on keys includes the role_id, id, and the role that no one is assigned to
users.merge(roles, left_on='role_id', right_on='id', how='right')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %%
#3 - What is the result of using an outer join on the DataFrames?
users.merge(roles, how='outer')
# Out:
#    id       name  role_id
# 0   1        bob      1.0
# 1   2        joe      2.0
# 2   3      sally      3.0
# 3   4       adam      3.0
# 4   5       jane      NaN
# 5   6       mike      NaN
# 6   1      admin      NaN
# 7   2     author      NaN
# 8   3   reviewer      NaN
# 9   4  commenter      NaN

# %%
#including the right_on and left_on keys returns:
users.merge(roles, left_on='role_id', right_on='id', how='outer')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %%
#4 - What happens if you drop the foreign keys from the DataFrames and try to merge them?
fkey_drop = users.drop(columns='role_id')

# %%
#the merge now incorrectly matches the data in the columns
pd.merge(fkey_drop, roles, on='id')
# Out:
#    id name_x     name_y
# 0   1    bob      admin
# 1   2    joe     author
# 2   3  sally   reviewer
# 3   4   adam  commenter

# %%
#5 - Load the mpg dataset from PyDataset.
mpg = data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
#6 - Output and read the documentation for the mpg dataset
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
#7 - How many rows and columns are in the dataset?
mpg.shape
# Out:
# (234, 11)

# %%
#8 - Check out your column names and perform any cleanup you may want on them.
mpg.rename(columns={'hwy': 'highway', 'cty': 'city'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
#9 - Display the summary statistics for the dataset.
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
# can also exclude numeric values with:
mpg.describe(exclude=np.number)
# Out:
#        manufacturer        model     trans  drv   fl class
# count           234          234       234  234  234   234
# unique           15           38        10    3    5     7
# top           dodge  caravan 2wd  auto(l4)    f    r   suv
# freq             37           11        83  106  168    62

# %%
#10 - How many different manufacturers are there?
#find the unique manufacturers
mpg.manufacturer.unique()
# Out:
# array(['audi', 'chevrolet', 'dodge', 'ford', 'honda', 'hyundai', 'jeep',
#        'land rover', 'lincoln', 'mercury', 'nissan', 'pontiac', 'subaru',
#        'toyota', 'volkswagen'], dtype=object)

# %%
#can also do 
mpg.manufacturer.value_counts()
#which will return a list of unique values and the counts of each
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# audi          18
# hyundai       14
# subaru        14
# nissan        13
# honda          9
# jeep           8
# pontiac        5
# land rover     4
# mercury        4
# lincoln        3
# Name: manufacturer, dtype: int64

# %%
#get the length of the series to get a count
len(mpg.manufacturer.unique())
# Out:
# 15

# %%
#11 - How many different models are there?
mpg.model.unique()
# Out:
# array(['a4', 'a4 quattro', 'a6 quattro', 'c1500 suburban 2wd', 'corvette',
#        'k1500 tahoe 4wd', 'malibu', 'caravan 2wd', 'dakota pickup 4wd',
#        'durango 4wd', 'ram 1500 pickup 4wd', 'expedition 2wd',
#        'explorer 4wd', 'f150 pickup 4wd', 'mustang', 'civic', 'sonata',
#        'tiburon', 'grand cherokee 4wd', 'range rover', 'navigator 2wd',
#        'mountaineer 4wd', 'altima', 'maxima', 'pathfinder 4wd',
#        'grand prix', 'forester awd', 'impreza awd', '4runner 4wd',
#        'camry', 'camry solara', 'corolla', 'land cruiser wagon 4wd',
#        'toyota tacoma 4wd', 'gti', 'jetta', 'new beetle', 'passat'],
#       dtype=object)

# %%
#get the length for a count
len(mpg.model.unique())
# Out:
# 38

# %%
#12 - Create a column named mileage_difference like you did in the DataFrames exercises; 
#this column should contain the difference between highway and city mileage for each car.
mpg['mileage_difference'] = mpg.hwy - mpg.cty

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    mileage_difference
# 1                  11
# 2                   8
# 3                  11
# 4                   9
# 5                  10

# %%
#13 - Create a column named average_mileage like you did in the DataFrames exercises; 
#this is the mean of the city and highway mileage.
mpg['average_mileage'] = (mpg.cty + mpg.hwy) / 2

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    mileage_difference  average_mileage
# 1                  11             23.5
# 2                   8             25.0
# 3                  11             25.5
# 4                   9             25.5
# 5                  10             21.0

# %%
#14 - Create a new column on the mpg dataset named is_automatic 
#that holds boolean values denoting whether the car has an automatic transmission.
mpg['is_automatic'] = np.where(mpg.trans.str.startswith('auto'), 'yes', 'no')

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    mileage_difference  average_mileage is_automatic
# 1                  11             23.5          yes
# 2                   8             25.0           no
# 3                  11             25.5           no
# 4                   9             25.5          yes
# 5                  10             21.0          yes

# %%
# or
mpg['is_automatic'] = np.where(mpg.trans.str.startswith('auto'), 'automatic', 'manual')

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    mileage_difference  average_mileage is_automatic
# 1                  11             23.5    automatic
# 2                   8             25.0       manual
# 3                  11             25.5       manual
# 4                   9             25.5    automatic
# 5                  10             21.0    automatic

# %%
#15 - Using the mpg dataset, 
#find out which which manufacturer has the best miles per gallon on average?
mpg.groupby('manufacturer').average_mileage.describe()
#overall stats info grouped by manufacturer
# Out:
#               count       mean       std   min     25%    50%     75%   max
# manufacturer
# audi           18.0  22.027778  1.996116  19.5  20.625  21.50  23.375  25.5
# chevrolet      19.0  18.447368  3.950720  12.5  15.250  19.00  21.250  26.0
# dodge          37.0  15.540541  3.005500  10.5  13.500  15.00  18.000  21.0
# ford           25.0  16.680000  2.540833  13.0  15.000  15.50  18.500  22.0
# honda           9.0  28.500000  1.984313  25.0  28.000  28.50  30.000  30.5
# hyundai        14.0  22.750000  1.794757  20.0  22.000  22.50  23.875  26.0
# jeep            8.0  15.562500  2.859040  10.5  14.750  16.00  17.125  19.5
# land rover      4.0  14.000000  1.154701  13.0  13.000  14.00  15.000  15.0
# lincoln         3.0  14.166667  0.763763  13.5  13.750  14.00  14.500  15.0
# mercury         4.0  15.625000  0.478714  15.0  15.375  15.75  16.000  16.0
# nissan         13.0  21.346154  4.214976  15.0  17.000  22.00  23.000  27.5
# ...

# %%
#return just manufacturer and average milage
mpg.groupby('manufacturer').average_mileage.mean()
# Out:
# manufacturer
# audi          22.027778
# chevrolet     18.447368
# dodge         15.540541
# ford          16.680000
# honda         28.500000
# hyundai       22.750000
# jeep          15.562500
# land rover    14.000000
# lincoln       14.166667
# mercury       15.625000
# nissan        21.346154
# pontiac       21.700000
# subaru        22.428571
# toyota        21.720588
# volkswagen    25.074074
# Name: average_mileage, dtype: float64

# %%
#return just manufacturer and average mileage
mpg.groupby('manufacturer').average_mileage.agg(['mean'])
# Out:
#                    mean
# manufacturer
# audi          22.027778
# chevrolet     18.447368
# dodge         15.540541
# ford          16.680000
# honda         28.500000
# hyundai       22.750000
# jeep          15.562500
# land rover    14.000000
# lincoln       14.166667
# mercury       15.625000
# nissan        21.346154
# pontiac       21.700000
# subaru        22.428571
# toyota        21.720588
# volkswagen    25.074074

# %%
#can also run like this so it can be sorted
mpg.groupby('manufacturer').average_mileage.mean().sort_values(ascending=False)
# Out:
# manufacturer
# honda         28.500000
# volkswagen    25.074074
# hyundai       22.750000
# subaru        22.428571
# audi          22.027778
# toyota        21.720588
# pontiac       21.700000
# nissan        21.346154
# chevrolet     18.447368
# ford          16.680000
# mercury       15.625000
# jeep          15.562500
# dodge         15.540541
# lincoln       14.166667
# land rover    14.000000
# Name: average_mileage, dtype: float64

# %%
#return just the manufacturer with best average mileage
mpg.groupby('manufacturer').average_mileage.agg(['mean']).nlargest(columns='mean', n=1, keep='all')
# Out:
#               mean
# manufacturer
# honda         28.5

# %%
#or
mpg.groupby('manufacturer').average_mileage.mean().nlargest(n=1, keep='all')
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %%
#16 - Do automatic or manual cars have better miles per gallon?
mpg.groupby('is_automatic').average_mileage.agg(['mean'])
#manual cars have better miles per gallon
# Out:
#                    mean
# is_automatic
# automatic     19.130573
# manual        22.227273

# %% [markdown]
# Exercises 3

# %%
#1 - Use your get_db_url function to help you explore the data from the chipotle database.
from env import host, username, password

get_db_url = f'mysql+pymysql://{username}:{password}@{host}/chipotle'

# %%
orders = pd.read_sql('SELECT * FROM orders;', get_db_url)

# %%
orders.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   object
#  6   quan_price          4622 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 252.9+ KB

# %%
#2 - What is the total price for each order?
#remove the '$' and change to a float for the item_price
orders['item_price'] = orders.item_price.str.replace('$', '').astype(float)
# Out:
# /var/folders/n7/fjb2f8gd5jg17xlxz1c85vhc0000gn/T/ipykernel_40653/1778853868.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   orders['item_price'] = orders.item_price.str.replace('$', '').astype(float)

# %%
#make a new column for the total for that line (quantity * item price)
orders['quan_price'] = orders.quantity * orders.item_price

# %%
#verify column changes
orders.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price  quan_price
# 0        2.39        2.39
# 1        3.39        3.39
# ...

# %%
#group by the order id and sum the order items
orders.groupby('order_id').item_price.agg(['sum'])
# Out:
#             sum
# order_id
# 1         11.56
# 2         16.98
# 3         12.67
# 4         21.00
# 5         13.70
# ...         ...
# 1830      23.00
# 1831      12.90
# 1832      13.20
# 1833      23.50
# 1834      28.75
#
# [1834 rows x 1 columns]

# %%
#3 - What are the most popular 3 items?
orders.groupby('item_name').quantity.agg('count').nlargest(n=3, keep='all')
# Out:
# item_name
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Name: quantity, dtype: int64

# %%
#4 - Which item has produced the most revenue?
orders.groupby('item_name').quan_price.agg(['sum']).nlargest(columns='sum', n=1, keep='all')
# Out:
#                   sum
# item_name
# Chicken Bowl  8044.63

# %%
##access the employees database##
get_db_url = f'mysql+pymysql://{username}:{password}@{host}/employees'
employees = pd.read_sql('SELECT * FROM employees;', get_db_url)
titles = pd.read_sql('SELECT * FROM titles;', get_db_url)

# %%
employees.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
titles.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
#5 - Join the employees and titles DataFrames together
emp_tit = employees.merge(titles, on='emp_no')

# %%
emp_tit.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date  \
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
#
#              title   from_date     to_date
# 0  Senior Engineer  1986-06-26  9999-01-01
# 1            Staff  1996-08-03  9999-01-01
# 2  Senior Engineer  1995-12-03  9999-01-01
# 3         Engineer  1986-12-01  1995-12-01
# 4  Senior Engineer  1995-12-01  9999-01-01

# %%
#6 - For each title, 
#find the hire date of the employee that was hired most recently with that title.
emp_tit.groupby('title').from_date.agg(['max'])
# Out:
#                            max
# title
# Assistant Engineer  2000-02-01
# Engineer            2002-08-01
# Manager             1996-08-30
# Senior Engineer     2002-08-01
# Senior Staff        2002-08-01
# Staff               2000-02-01
# Technique Leader    2000-02-01

# %%
#7 - Write the code necessary to create a cross tabulation of the number of titles by department. 
#(Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

#pull the department names and the titles from the database
sql = '''
SELECT d.dept_name, t.title
FROM departments AS d
JOIN dept_emp AS de USING(dept_no)
JOIN titles AS t USING(emp_no);'''

depts_titles = pd.read_sql(sql, get_db_url)
depts_titles
# Out:
#                dept_name         title
# 0       Customer Service         Staff
# 1       Customer Service  Senior Staff
# 2       Customer Service         Staff
# 3       Customer Service  Senior Staff
# 4       Customer Service         Staff
# ...                  ...           ...
# 489898             Sales  Senior Staff
# 489899             Sales         Staff
# 489900             Sales         Staff
# 489901             Sales  Senior Staff
# 489902             Sales         Staff
#
# [489903 rows x 2 columns]

# %%
#cross tabulate the department names against the titles
pd.crosstab(depts_titles.dept_name, depts_titles.title)
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                   298      2362        4             2027
# Development                       7769     58135        2            49326
# Finance                              0         0        2                0
# Human Resources                      0         0        2                0
# Marketing                            0         0        2                0
# Production                        6445     49649        4            42205
# Quality Management                1831     13852        4            11864
# Research                           378      2986        2             2570
# Sales                                0         0        2                0
#
# title               Senior Staff  Staff  Technique Leader
# dept_name
# Customer Service           13925  16150               309
# Development                 1247   1424              7683
# ...
