# %% [markdown]
# Dataframes Exercises

# %%
import numpy as np
import pandas as pd
from pydataset import data

# %%
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df)
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     12 non-null     object
#  1   math     12 non-null     int64
#  2   english  12 non-null     int64
#  3   reading  12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 512.0+ bytes

# %%
df.describe()
# Out:
#             math    english    reading
# count  12.000000  12.000000  12.000000
# mean   84.833333  77.666667  86.500000
# std    11.134168  13.371158   9.643651
# min    62.000000  62.000000  67.000000
# 25%    78.500000  63.750000  80.750000
# 50%    90.000000  77.500000  89.000000
# 75%    92.250000  86.750000  93.250000
# max    98.000000  99.000000  98.000000

# %% [markdown]
# #1a.  Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
df['passing_english'] = df.english > 70

# %%
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %% [markdown]
# #1b.  Sort the english grades by the passing_english column. How are duplicates handled?

# %%
df.sort_values(by='passing_english')
#duplicate values are grouped together and sorted by index unless otherwise specified.
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# #1c.  Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(by=['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %% [markdown]
# #1d.  Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.sort_values(by=['passing_english', 'english'])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# #1e.  Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df['overall_grade'] = df.math + df.english + df.reading

# %%
df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True            227
# 1      Jane    88       79       67             True            234
# 2     Suzie    94       74       95             True            263
# 3     Billy    98       96       88             True            282
# 4       Ada    77       92       98             True            267
# 5      John    79       76       93             True            248
# 6    Thomas    82       64       81            False            227
# 7     Marie    93       63       90            False            246
# 8    Albert    92       62       87            False            241
# 9   Richard    69       80       94             True            243
# 10    Isaac    92       99       93             True            284
# 11     Alan    92       62       72            False            226

# %%
#better way to sum the grades across the column
#axis=1 -- sum by row (rather than the default of axis=0 which sums by column)
df[['math', 'english', 'reading']].sum(axis=1)
# Out:
# 0     227
# 1     234
# 2     263
# 3     282
# 4     267
# 5     248
# 6     227
# 7     246
# 8     241
# 9     243
# 10    284
# 11    226
# dtype: int64

# %%
#overall average grade
df['overall_average'] = (df[['math', 'english', 'reading']].sum(axis=1)) / 3

# %%
df
# Out:
#        name  math  english  reading  passing_english  overall_average
# 0     Sally    62       85       80             True        75.666667
# 1      Jane    88       79       67             True        78.000000
# 2     Suzie    94       74       95             True        87.666667
# 3     Billy    98       96       88             True        94.000000
# 4       Ada    77       92       98             True        89.000000
# 5      John    79       76       93             True        82.666667
# 6    Thomas    82       64       81            False        75.666667
# 7     Marie    93       63       90            False        82.000000
# 8    Albert    92       62       87            False        80.333333
# 9   Richard    69       80       94             True        81.000000
# 10    Isaac    92       99       93             True        94.666667
# 11     Alan    92       62       72            False        75.333333

# %% [markdown]
# #2 Load the mpg dataset.

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg = data('mpg')

# %% [markdown]
# #2a How many rows and columns are there?

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
#there are 11 columns and 234 rows in the 'mpg' dataframe from .info()

# %%
#can also use:
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# #2b What are the data types of each column?

# %%
#columns manufacturer, model, trans, drv, fl, and class are object; 
#column displ is float; 
#columns year, cyl, cty, and hwy are int.

# %% [markdown]
# #2c Summarize the dataframe with .info and .describe

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# #2d Rename the cty column to city

# %%
mpg.rename(columns={'cty': 'city'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %% [markdown]
# #2e Rename the hwy column to highway

# %%
mpg.rename(columns={'hwy': 'highway'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %% [markdown]
# #2f Do any cars have better city mileage than highway mileage?

# %%
mpg[mpg.cty > mpg.hwy]
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, cty, hwy, fl, class, mileage_difference]
# Index: []

# %%
#returns an empty table 
#because there are not any entries where the city value is greater than the highway value

# %% [markdown]
# #2g Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.hwy - mpg.cty

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference
# 1    compact                  11
# 2    compact                   8
# ...

# %% [markdown]
# #2h Which car (or cars) has the highest mileage difference?

# %%
mpg.sort_values(by='mileage_difference', ascending=False).head()
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  cty  hwy fl  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f   24   36  c
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f   29   41  d
# 1           audi          a4    1.8  1999    4  auto(l5)   f   18   29  p
# 229   volkswagen      passat    1.8  1999    4  auto(l5)   f   18   29  p
# 36     chevrolet      malibu    3.5  2008    6  auto(l4)   f   18   29  r
#
#           class  mileage_difference
# 107  subcompact                  12
# 223  subcompact                  12
# 1       compact                  11
# 229     midsize                  11
# 36      midsize                  11

# %% [markdown]
# #2i Which compact class car has the lowest highway mileage? The best?

# %%
# top five lowest
mpg[mpg['class'] == 'compact'].sort_values(by='hwy').head()
# Out:
#     manufacturer        model  displ  year  cyl       trans drv  cty  hwy fl  \
# 220   volkswagen        jetta    2.8  1999    6    auto(l4)   f   16   23  r
# 221   volkswagen        jetta    2.8  1999    6  manual(m5)   f   17   24  r
# 212   volkswagen          gti    2.8  1999    6  manual(m5)   f   17   24  r
# 172       subaru  impreza awd    2.5  2008    4  manual(m5)   4   19   25  p
# 170       subaru  impreza awd    2.5  2008    4    auto(s4)   4   20   25  p
#
#        class  mileage_difference
# 220  compact                   7
# 221  compact                   7
# 212  compact                   7
# 172  compact                   6
# 170  compact                   5

# %%
# top five highest
mpg[mpg['class'] == 'compact'].sort_values(by='hwy', ascending=False).head()
# Out:
#     manufacturer    model  displ  year  cyl       trans drv  cty  hwy fl  \
# 213   volkswagen    jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 197       toyota  corolla    1.8  2008    4  manual(m5)   f   28   37  r
# 196       toyota  corolla    1.8  1999    4  manual(m5)   f   26   35  r
# 198       toyota  corolla    1.8  2008    4    auto(l4)   f   26   35  r
# 195       toyota  corolla    1.8  1999    4    auto(l4)   f   24   33  r
#
#        class  mileage_difference
# 213  compact                  11
# 197  compact                   9
# 196  compact                   9
# 198  compact                   9
# 195  compact                   9

# %% [markdown]
# #2j Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.cty + mpg.hwy) / 2

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    mileage_difference  average_mileage
# 1                  11             23.5
# 2                   8             25.0
# 3                  11             25.5
# 4                   9             25.5
# 5                  10             21.0

# %%
#can also use:
mpg[['cty', 'hwy']].mean(axis=1)
#instead of (mpg.cty + mpg.hwy) / 2 which was used above
# Out:
# 1      23.5
# 2      25.0
# 3      25.5
# 4      25.5
# 5      21.0
#        ...
# 230    23.5
# 231    25.0
# 232    21.0
# 233    22.0
# 234    21.5
# Length: 234, dtype: float64

# %% [markdown]
# #2k Which dodge car has the best average mileage? The worst?

# %%
#top five dodge with lowest average mileage
mpg[mpg.manufacturer == 'dodge'].sort_values(by='average_mileage').head()
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  cty  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 74        dodge  ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4   11
#
#     hwy fl   class  mileage_difference  average_mileage
# 70   12  e  pickup                   3             10.5
# 66   12  e  pickup                   3             10.5
# 60   12  e     suv                   3             10.5
# 55   12  e  pickup                   3             10.5
# 74   15  r  pickup                   4             13.0

# %%
# top five dodge with highest average mileage
mpg[mpg.manufacturer == 'dodge'].sort_values(by='average_mileage', ascending=False).head()
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  cty  hwy fl  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f   18   24  r
# 42        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f   17   24  r
# 43        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f   17   24  r
# 39        dodge  caravan 2wd    3.0  1999    6  auto(l4)   f   17   24  r
# 47        dodge  caravan 2wd    3.8  2008    6  auto(l6)   f   16   23  r
#
#       class  mileage_difference  average_mileage
# 38  minivan                   6             21.0
# 42  minivan                   7             20.5
# 43  minivan                   7             20.5
# 39  minivan                   7             20.5
# 47  minivan                   7             19.5

# %% [markdown]
#  #3 Load the Mammals dataset

# %%
mammals = data('Mammals')

# %% [markdown]
# #3a How many rows and columns are there?

# %%
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
# the mammals dataframe has 4 columns and 107 rows

# %%
#can also use:
mammals.shape
# Out:
# (107, 4)

# %% [markdown]
# #3b What are the data types?

# %%
#from mammals.info()
#the weight and speed columns are floats
#the hoppers and specials are boolean

# %% [markdown]
# #3c Summarize the dataframe with .info and .describe

# %%
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %% [markdown]
# #3d What is the the weight of the fastest animal?

# %%
mammals.sort_values(by='speed', ascending=False).head(1)
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
#the fastest animal has a speed of 110.0 and a weight of 55.0

# %% [markdown]
# #3e What is the overal percentage of specials?

# %%
mammals['specials'].value_counts(normalize=True)
# Out:
# False    0.906542
# True     0.093458
# Name: specials, dtype: float64

# %%
#the above will return the percentages of true and false as a decimal

# %%
mammals['specials'].value_counts(normalize=True).mul(100).astype(str)+'%'
# Out:
# False    90.65420560747664%
# True     9.345794392523365%
# Name: specials, dtype: object

# %%
# the above will return the precentages as a string with a '%'

# %% [markdown]
# #3f How many animals are hoppers that are above the median speed? What percentage is this?

# %%
#get the median animal speed
mammals['speed'].median()
# Out:
# 48.0

# %%
#returns the rows where the animal is a hopper and has a speed above 48 (median speed)
mammals[(mammals.speed > 48) & (mammals.hoppers==True)]
# Out:
#      weight  speed  hoppers  specials
# 96      4.6   64.0     True     False
# 97      4.4   72.0     True     False
# 98      4.0   72.0     True     False
# 99      3.5   56.0     True     False
# 100     2.0   64.0     True     False
# 101     1.9   56.0     True     False
# 102     1.5   50.0     True     False

# %%
#assigns the above rows to a variable 
#so we can run a .describe() to get a count as well as other stats info
above_median_hoppers = mammals[(mammals.speed > 48) & (mammals.hoppers==True)]
above_median_hoppers.describe()
# Out:
#          weight      speed
# count  7.000000   7.000000
# mean   3.128571  62.000000
# std    1.298351   8.406347
# min    1.500000  50.000000
# 25%    1.950000  56.000000
# 50%    3.500000  64.000000
# 75%    4.200000  68.000000
# max    4.600000  72.000000

# %%
#what percentage is this?
